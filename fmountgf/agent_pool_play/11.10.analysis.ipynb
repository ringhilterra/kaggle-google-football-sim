# %% [markdown]
# Analysis of results

# %% [markdown]
# Want to look at academy 3 vs 1

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Academy 3 vs 1 with keeper

# %%
RESULTS_DIR = 'pool_play_results/11-11-2020-07-18-52/'

# %%
config_df = pd.read_csv(RESULTS_DIR + 'config.csv')
config_df
# Out:
#                      0                           1
# 0           save_video                       False
# 1        scenario_name  academy_3_vs_1_with_keeper
# 2  running_in_notebook                       False
# 3         episodeSteps                         500
# 4           num_rounds                          10

# %%
results_df = pd.read_csv(RESULTS_DIR + 'results.csv')
print(results_df.shape)
results_df.head(2)
# Out:
# (490, 10)
#                      scenario  round  \
# 0  academy_3_vs_1_with_keeper      0
# 1  academy_3_vs_1_with_keeper      0
#
#                                                left_agent  \
# 0  ../submit_agents/tunable-baseline-bot/submission_v6.py
# 1  ../submit_agents/tunable-baseline-bot/submission_v6.py
#
#                                               right_agent  left_score  \
# 0  ../submit_agents/tunable-baseline-bot/submission_v6.py           0
# 1   ../submit_agents/best-open-rules-bot/submission_v2.py           0
#
#    right_score  left_reward  right_reward left_status right_status
# 0            0          0.0             0        DONE         DONE
# 1            0          0.0             0        DONE         DONE

# %%
score_df = pd.read_csv(RESULTS_DIR + 'scoreboard.csv')
print(score_df.shape)
score_df
# Out:
# (7, 9)
#                 scenario_name  \
# 0  academy_3_vs_1_with_keeper
# 1  academy_3_vs_1_with_keeper
# 2  academy_3_vs_1_with_keeper
# 3  academy_3_vs_1_with_keeper
# 4  academy_3_vs_1_with_keeper
# 5  academy_3_vs_1_with_keeper
# 6  academy_3_vs_1_with_keeper
#
#                                                                agent  \
# 0  ../submit_agents/gfootball-with-memory-patterns/submission_v55.py
# 1              ../submit_agents/best-open-rules-bot/submission_v2.py
# 2  ../submit_agents/gfootball-with-memory-patterns/submission_v32.py
# 3             ../submit_agents/tunable-baseline-bot/submission_v6.py
# 4  ../submit_agents/gfootball-with-memory-patterns/submission_v43.py
# 5                   ../submit_agents/maraud_wingers/submission_v1.py
# 6  ../submit_agents/gfootball-with-memory-patterns/submission_v15.py
#
#    games_played  num_wins  num_losses  num_ties  goals_for  goals_against  \
# 0           140        16           8       116         16              8
# ...

# %% [markdown]
# ## Kaggle 11 vs 11 (1500 steps)

# %%
RESULTS_DIR = 'pool_play_results/11-11-2020-09-17-04/'

# %%
config_df = pd.read_csv(RESULTS_DIR + 'config.csv')
config_df
# Out:
#                      0                1
# 0           save_video            False
# 1        scenario_name  11_vs_11_kaggle
# 2  running_in_notebook            False
# 3         episodeSteps             1500
# 4           num_rounds                5

# %%
results_df = pd.read_csv(RESULTS_DIR + 'results.csv')
print(results_df.shape)
results_df.head(2)
# Out:
# (245, 10)
#           scenario  round  \
# 0  11_vs_11_kaggle      0
# 1  11_vs_11_kaggle      0
#
#                                                left_agent  \
# 0  ../submit_agents/tunable-baseline-bot/submission_v6.py
# 1  ../submit_agents/tunable-baseline-bot/submission_v6.py
#
#                                               right_agent  left_score  \
# 0  ../submit_agents/tunable-baseline-bot/submission_v6.py           2
# 1   ../submit_agents/best-open-rules-bot/submission_v2.py           0
#
#    right_score  left_reward  right_reward left_status right_status
# 0            1            1            -1        DONE         DONE
# 1            2           -2             2        DONE         DONE

# %%
score_df = pd.read_csv(RESULTS_DIR + 'scoreboard.csv')
print(score_df.shape)
score_df
# Out:
# (7, 9)
#      scenario_name  \
# 0  11_vs_11_kaggle
# 1  11_vs_11_kaggle
# 2  11_vs_11_kaggle
# 3  11_vs_11_kaggle
# 4  11_vs_11_kaggle
# 5  11_vs_11_kaggle
# 6  11_vs_11_kaggle
#
#                                                                agent  \
# 0  ../submit_agents/gfootball-with-memory-patterns/submission_v32.py
# 1  ../submit_agents/gfootball-with-memory-patterns/submission_v43.py
# 2  ../submit_agents/gfootball-with-memory-patterns/submission_v55.py
# 3  ../submit_agents/gfootball-with-memory-patterns/submission_v15.py
# 4              ../submit_agents/best-open-rules-bot/submission_v2.py
# 5                   ../submit_agents/maraud_wingers/submission_v1.py
# 6             ../submit_agents/tunable-baseline-bot/submission_v6.py
#
#    games_played  num_wins  num_losses  num_ties  goals_for  goals_against  \
# 0            70        33          18        19        109             82
# 1            70        30          19        21         96             70
# ...
